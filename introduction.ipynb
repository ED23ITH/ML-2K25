# %% [markdown]
# <a href="https://colab.research.google.com/github/ED23ITH/ML-2K25/blob/ML-1/introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Skill Morph")
# Out:
# Skill Morph

# %% [markdown]
# ### chapter **1** **bold text**

# %%
23+27
# Out:
# 50
